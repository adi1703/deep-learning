# %% [markdown]
# <center><u><h1>Assignment-1: Introduction to Time Series Analysis</center></u></h1>
#
# Hello everyone!! Welcome to the first assignment of Time Series Analysis course.
#
# ![ts1.1.png](https://amandawonglee.com/wp-content/uploads/2018/06/Hello_Welcome_.jpg)
#
# So, get yourselves ready because you are going to learn something very fascinating in this course!! <br><br>
# In this assignment, as the name suggests, you will have a glimpse of what exactly time series analysis is and where is it used.
#
# <h3><u>Table of contents</h3></u>
#
#
# 1.   What is time series analysis?
# 2.   Where is time series analysis used?
# 3.   Real world example of Time Series Analysis
# 4.   Components of time series.
# 5.   Visualization of time series data
#
# <br>
#
# ##So let's get started!!

# %% [markdown]
# <h2><u>What is time series analysis?</h2></u>
#
# A time series analysis is a method of studying a collection of data points over a period of time. Instead of capturing data points intermittently or arbitrarily, time series analyzers record data points at constant intervals over a predetermined length of time.
#
# ![ts1.2.png](https://cdn.corporatefinanceinstitute.com/assets/Time-Series-Analysis-1024x729.png)
#
# As you can interpret from the above image, in time series the response variable is studied against time. The time can be in days,weeks,months,years or even minutes. Time series analysis can be used to demonstrate how variables change over time. Time is an important variable since it reveals how the data changes over time, as well as the final outcomes. It also guarantees that any trends or patterns found aren't outliers and that seasonal variation is taken into account. Time series data can also be used for forecasting, or anticipating future data based on previous data.
#
# Refer to the below given video to understand about it better.

# %%
###Refer Video
from IPython.display import YouTubeVideo
YouTubeVideo('RxhmWTxrTs0', width=700, height=400)

# %% [markdown]
# <h2><u>Where is time series analysis used?</h2></u>
#
# Non-stationary data—that is, data that is constantly varying over time or is affected by time—is analysed using time series analysis. Because currency and sales are continually changing, industries including banking, retail, and economics regularly use time series analysis. Similarly, time series analysis is perfect for forecasting weather changes, allowing meteorologists to predict everything from tomorrow's weather report to climate change in future years.
#
# ![ts1.3.png](https://lh5.googleusercontent.com/yZWCx5pz0KKyvM1ud2dPh-4IxAZQjfd0uwJOM_73oQ4ajMyJLSM5kyd8Dz6hwaiP46nPfP_uzlI3hFvCiCj_DFAMwEP1P3uuixYK_oDLe60VtEllvUrGweYNUG4bpYJEW6lE4XtC)
#
# Do refer to the video given below to know more applications of time series analysis

# %%
###Refer Video
YouTubeVideo('b0oNfeJlSPA', width=700, height=400)

# %% [markdown]
# Given below are some major domains where time series analysis is used:
#
#
# 1.   Time series in Financial and Business Domain
# 2.   Time series in Medical Domain
# 3.   Time Series in Astronomy
# 4.   Time series in Forecasting Weather
# 5.   Time series in Census analysis
#
# Reference documentation:https://www.analyticssteps.com/blogs/5-applications-time-series-analysis

# %% [markdown]
# <h2><u>Real world example of Time Series Analysis</h2></u>
#
# You saw some of the general applications of time series analysis above. But now let's see an example in detail.<br><br>
# <b><u>Antidiabetic drug sale</b></u>:<br>
# This is a real world example of applications and use cases of time series analysis. It shows how the sales of drugs for diabetes control has grown overtime. The data ranges from 1995 to 2005 which is a 10 year tenure. Below is the visualization of the antidiabetic drug sales. It shows that the sales has increased continuously from 1995 to 2005. The reason could be changing lifestyle of people which results into an unhealthy life leading to condition like diabetes. Due to rapid urbanisation and busy schedules in past years, people have accepted western lifestyle that inclued imabalaned and unhealthy diet, lack of excerise and fitness, bad sleep pattern, etc. Using this time series data, the sales of this drug can be predicted for further years which can then be used for proper planning of distribution of the medicine and also planning ways to control occurence of diabetes in people.
#
# ![ts1.12.png](data:image/png;base64,...)
#
# <br>
#
# <b>We will be plotting the same data ahead in visualization of time series data topic.</b><br><br>There are many such real world use cases of time series analysis. Do explore the internet for knowing other real world applications.

# %% [markdown]
# <h2><u>Components of time series</h2></u>
#
# The components of a time series are the many reasons or forces that affect the values of an observation in a time series.
#
# ![ts1.5.png](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F3526173%2F9534e2d240cbe31285ba6787b121ea95%2FIntroduction-to-Time-Series-Data.jpg?generation=1595620883447392&alt=media)
#
# ### Kindly watch the video given below.

# %%
###Refer Video
YouTubeVideo('sn1tL_ZEKHc', width=700, height=400)

# %% [markdown]
# Various components of time series are:
#
#
# 1.   Trend:<br>
# A time series trend is its long-term pattern. A trend exists when there is a long-term increase or decrease in the data. It does not have to be linear. Sometimes we will refer to a trend as “changing direction,” when it might go from an increasing trend to a decreasing trend. Depending on whether the time series exhibits an increasing or declining long term pattern, a trend might be positive or negative.
# A time series is stationary in the mean if it does not display an increasing or decreasing tendency.
#
# ![ts1.6.png](https://productimize.com/wp-content/uploads/2019/08/Component-in-Time-Series_Trend.png)
#
# 2.   Seasonality<br>
# When seasonal elements such as the time of year or the day of the week affect a time series, it is called a seasonal pattern. Seasonality has a predictable and defined frequency.
#
# ![ts1.7.png](https://www.vosesoftware.com/riskwiki/images/image1858.gif)
#
# 3.   Cyclicity<br>
# When data shows increases and falls that are not of a constant frequency, it is called a cycle. Economic conditions are usually to blame for these variations, which are often linked to the "business cycle." Many individuals mix up cyclic and seasonal behaviour, yet the two are quite different. The variations are cyclic if they do not have a defined frequency; the pattern is seasonal if the frequency is constant and linked to some feature of the calendar.
#
# ![ts1.8.png](https://i.ytimg.com/vi/ca0rDWo7IpI/maxresdefault.jpg)
#
# 4.  Irregularity<br>
# The irregular component arises from non-systematic and, in certain cases, unpredictable short-term variations in a series, such as unusual weather patterns.
#
# ![ts1.9.png](https://www.datascienceprophet.com/wp-content/uploads/2020/08/irregular.jpg)

# %% [markdown]
# Given below is the difference chart between all the time series components based on various factors.
#
# ![ts1.10.png](https://editor.analyticsvidhya.com/uploads/39815Components%20of%20Time%20Series%20Analysis.png)

# %% [markdown]
# <h2><u>Visualization of time series data</h2></u>
# After knowing about time series analysis and it's uses, its time to get into some coding. Before beginning with the practical implementation, watch a video so that you get a baisc idea about visualization of time series data.

# %%
###Refer Video
YouTubeVideo('ESBVBXtDa78', width=700, height=400)

# %% [markdown]
# Now we will visualize a sample time series data to understand how a time series data and it's components exactly are. We will be using pandas library to handle the data and matplotlib library for visualizing the data. <br>
# So lets begin!!<br><br>
# Begin by importing the required libraries:<br>
#
#
# 1.   pandas: for storing and analyzing the data
# 2.   matplotlib: for visualizing the data using plots and graphs

# %%
## importing the pandas and matplotlib library
import pandas as pd
import matplotlib.pyplot as plt
import math

# %% [markdown]
# The dataset used in the project is present in the google drive. So the drive has to be first mounted to use the dataset. For that use the drive library from google.colab and then mount the drive using mount function.

# %%
# import drive from google.colab
from google.colab import drive
# mount the drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, load the dataset using read_csv method of pandas in the df variable. <br><br><b><u>Download the dataset from the given link and upload it in your drive.</b></u> https://drive.google.com/file/d/1jIC1VmtAUN5Tl0tyAf0CvefAKjZewODm/view?usp=sharing.  <br><br>After uploading use your dataset link for reading the data in the read_csv method. The dataset is a small dataset with several rows and has two columns like date and value. This is an example of time series data as the feature value is recorded based on date. The date column is set as the index column. parse_dates attribute is to parse the dates so that it can be represented as an array of datetimes. parse_dates is used to make the dates uniform as dates can be present in different formats. Refer documentation: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html. <br>
# Top 5 rows of the dataset are printed using the head function.

# %%
## read the dataset
df = pd.read_csv(
    '/content/times_series1.csv',
    parse_dates=['date'],
    index_col='date'
)
## use the head method from pandas to view the dataset
print(df.head())
# Out:
#                value
# date
# 1991-07-01  3.526591
# 1991-08-01  3.180891
# 1991-09-01  3.252221
# 1991-10-01  3.611003
# 1991-11-01  3.565869

# %% [markdown]
# Now its time to actually visualize the data. For that define a plot_df function having attributes like df(dataframe to be plotted), x(columns on X-axis), y(columns on Y-axis), title(title of the graph), xlabel(name given to the X-axis), ylabel(name given to the Y-axis), dpi(dots per inch). <br>
# <br><b>Here plot the graph by keeping dates(index) on X-axis and values on Y-axis.</b>
#
# Refer the documentation to know more about matplotlib:https://matplotlib.org/stable/tutorials/index

# %%
# Draw Plot
# define plot_df function for plotting
# parameters: df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100

    # set plot figure size 16,5 and dpi as 100

    # plot using plot() method

    # set title name, xlabel and ylabel

    # show the plot

def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):

    # figure size and quality
    plt.figure(figsize=(16,5), dpi=dpi)

    # plot graph
    plt.plot(x, y)

    # labels and title
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    # display graph
    plt.show()
# call the plot_df function and title as title='Monthly anti-diabetic drug sales in Australia from 1992 to 2008.')
plot_df(
    df,
    x=df.index,
    y=df.value,
    title='Monthly anti-diabetic drug sales in Australia from 1992 to 2008.'
)

# %% [markdown]
# From the above plot you can see that the time series data that we have used has an increasing trend over the years. It also has seasonality as there are similar periodic changes in the data.<br><br> In the above plotting code, you saw the parameter dpi which is dots per inches. It represents the number of pixels per inch in the figure. The default value for dpi in matplotlib.pyplot.figure() function is 100.
#
# ###Refer the below given video:

# %%
###Refer Video
YouTubeVideo('gocI8zDv05c', width=700, height=400)

# %% [markdown]
# For understanding other components as well lets consider other datasets. <br><br><b><u>Download the three datasets from the given links and upload them in your drive.</b></u><br>
# For df2: https://drive.google.com/file/d/14so17QpSV_bkUalfBgtWHZ3LLR4bFCvt/view?usp=sharing. <br>
# For df3: https://drive.google.com/file/d/1fvMWzd1KDk6zuey-s26wU9ziye6Xrlqh/view?usp=sharing.<br>
# For df4: https://drive.google.com/file/d/1gojwIYdOwLa9aol2Tk7fELi1naLCrUyY/view?usp=sharing. <br>After uploading, use your dataset links from the drive for reading the data in the read_csv method.First create three subplots as we are using other three datasets. You will be seeing the trend, seasonality and trend+seasonality type of data. All the three datasets are first read using read_csv method of pandas and stored in different variables. Then they are plotted using the plot function of matplotlib.

# %%
# set 3 subplots of 20,4 size and 100 dpi


# read time_series2.csv for trend only

# plot the data on 0th axis


# read time_series3.csv for seasonality only

# plot the data on 1st axis


# read time_series4.csv for tre nd and seasonality only

# plot the data on 2nd axis
fig, axes = plt.subplots(3, 1, figsize=(20,4), dpi=100)

# dataset with trend only
df1 = pd.read_csv(
    '/content/times_series2.csv',
    parse_dates=['date'],
    index_col='date'
)

# plot on first axis
axes[0].plot(df1.index, df1.value)
axes[0].set_title("Trend Only")

df2 = pd.read_csv(
    '/content/times_series3.csv',
    parse_dates=['date'],
    index_col='date'
)

# plot on second axis
axes[1].plot(df2.index, df2.value)
axes[1].set_title("Seasonality Only")

df3 = pd.read_csv(
    '/content/times_series4.csv',
    parse_dates=['date'],
    index_col='date'
)

# plot on third axis
axes[2].plot(df3.index, df3.value)
axes[2].set_title("Trend + Seasonality")

# spacing
plt.tight_layout()

# show plots
plt.show()

# %% [markdown]
# From the above figures you can see that the first dataset has an increasing trend, second has seasonality and third dataset has both trend and seasonality. This tells us that different time series data have different components. Similarly, you can visualize other datasets of your choice, understand the pattern and recognize the components present in the data.

# %% [markdown]
# So friends, we have come to an end of this assignment. Hope you understood the concepts, if not then do not hestitate to look back again at it. We learnt about what is time series analysis and where it is used. Also you saw components of time series data and how to visualize them. Keep practising until next assignment comes in. <br><br>
# ## Do fill the feedback form given below:
# [Feedback form](https://forms.zohopublic.in/cloudyml/form/CloudyMLDeepLearningFeedbackForm/formperma/VCFbldnXAnbcgAIl0lWv2blgHdSldheO4RfktMdgK7)
# <br><br> See you then!!
#
# ![ts1.11.png](https://media.istockphoto.com/photos/text-sign-showing-thank-you-see-you-again-conceptual-photo-gratitude-picture-id1006228936?k=20&m=1006228936&s=612x612&w=0&h=LLW3ZeFBH3VANWgRI-ra8nRMvAx7I6MEPl6ve8t9Rrs=)
